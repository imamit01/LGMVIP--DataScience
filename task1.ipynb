# %% [markdown]
# #  Iris Flowers Classification ML Project
# ### Name - Amit Kumar
# ### Task-1

# %% [markdown]
# #### Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
df1 = pd.read_csv("iris.data")
names= ["sepal_length","sepal_width ","petal_length", "petal_width ","class"]
df1.to_csv("Iris.csv", header=names, index=False)
data = pd.read_csv("Iris.csv")
data.head()
# Out:
#    sepal_length  sepal_width   petal_length  petal_width         class
# 0           4.9           3.0           1.4           0.2  Iris-setosa
# 1           4.7           3.2           1.3           0.2  Iris-setosa
# 2           4.6           3.1           1.5           0.2  Iris-setosa
# 3           5.0           3.6           1.4           0.2  Iris-setosa
# 4           5.4           3.9           1.7           0.4  Iris-setosa

# %%
print(data)
print(data.head()) #first five value
# Out:
#      sepal_length  sepal_width   petal_length  petal_width            class
# 0             4.9           3.0           1.4           0.2     Iris-setosa
# 1             4.7           3.2           1.3           0.2     Iris-setosa
# 2             4.6           3.1           1.5           0.2     Iris-setosa
# 3             5.0           3.6           1.4           0.2     Iris-setosa
# 4             5.4           3.9           1.7           0.4     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 144           6.7           3.0           5.2           2.3  Iris-virginica
# 145           6.3           2.5           5.0           1.9  Iris-virginica
# 146           6.5           3.0           5.2           2.0  Iris-virginica
# 147           6.2           3.4           5.4           2.3  Iris-virginica
# 148           5.9           3.0           5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]
# ...

# %%
#describe data
data.describe()
# Out:
#        sepal_length  sepal_width   petal_length  petal_width
# count    149.000000    149.000000    149.000000    149.000000
# mean       5.848322      3.051007      3.774497      1.205369
# std        0.828594      0.433499      1.759651      0.761292
# min        4.300000      2.000000      1.000000      0.100000
# 25%        5.100000      2.800000      1.600000      0.300000
# 50%        5.800000      3.000000      4.400000      1.300000
# 75%        6.400000      3.300000      5.100000      1.800000
# max        7.900000      4.400000      6.900000      2.500000

# %%
#maxm
data.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# class           Iris-virginica
# dtype: object

# %%
#min
data.min()
# Out:
# sepal_length            4.3
# sepal_width               2
# petal_length              1
# petal_width             0.1
# class           Iris-setosa
# dtype: object

# %%
data.corr()
# Out:
#               sepal_length  sepal_width   petal_length  petal_width
# sepal_length      1.000000     -0.103784      0.871283      0.816971
# sepal_width      -0.103784      1.000000     -0.415218     -0.350733
# petal_length      0.871283     -0.415218      1.000000      0.962314
# petal_width       0.816971     -0.350733      0.962314      1.000000

# %% [markdown]
# ## Data Visualization
# ### ScatterPlot

# %%
f,ax= plt.subplots(figsize=(20,10))
ax= sns.scatterplot('sepal_length','sepal_width ',hue='class',data =data)
plt.title("Sepal Length vs Sepal Width\n", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width\n')

# %%
f,ax= plt.subplots(figsize=(20,10))
ax= sns.scatterplot('petal_length','petal_width ',hue='class',data =data)
plt.title("petal Length vs petal Width\n", fontsize=20)
# Out:
# Text(0.5, 1.0, 'petal Length vs petal Width\n')

# %% [markdown]
# ## HeatMap

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, linewidths=0.7, fmt= '.3f')
plt.show()

# %%
X = data["sepal_length"].values.reshape(-1,1)
print(X)
# Out:
# [[4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [4.3]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [4.6]
#  [5.1]
#  [4.8]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
#  [5. ]
#  [5.6]
#  [5.7]
#  [5.7]
#  [6.2]
#  [5.1]
#  [5.7]
#  [6.3]
#  [5.8]
#  [7.1]
#  [6.3]
#  [6.5]
#  [7.6]
#  [4.9]
#  [7.3]
#  [6.7]
#  [7.2]
#  [6.5]
#  [6.4]
# ...

# %%
A= data["sepal_width "].values.reshape(-1,1)
print(A)
# Out:
# [[3. ]
#  [3.2]
#  [3.1]
#  [3.6]
#  [3.9]
#  [3.4]
#  [3.4]
#  [2.9]
#  [3.1]
#  [3.7]
#  [3.4]
#  [3. ]
#  [3. ]
#  [4. ]
#  [4.4]
#  [3.9]
#  [3.5]
#  [3.8]
#  [3.8]
#  [3.4]
#  [3.7]
#  [3.6]
#  [3.3]
#  [3.4]
#  [3. ]
#  [3.4]
#  [3.5]
#  [3.4]
#  [3.2]
#  [3.1]
#  [3.4]
#  [4.1]
#  [4.2]
#  [3.1]
#  [3.2]
#  [3.5]
#  [3.1]
#  [3. ]
#  [3.4]
#  [3.5]
#  [2.3]
#  [3.2]
#  [3.5]
#  [3.8]
#  [3. ]
#  [3.8]
#  [3.2]
#  [3.7]
#  [3.3]
#  [3.2]
#  [3.2]
#  [3.1]
#  [2.3]
#  [2.8]
#  [2.8]
#  [3.3]
#  [2.4]
#  [2.9]
#  [2.7]
#  [2. ]
#  [3. ]
#  [2.2]
#  [2.9]
#  [2.9]
#  [3.1]
#  [3. ]
#  [2.7]
#  [2.2]
#  [2.5]
#  [3.2]
#  [2.8]
#  [2.5]
#  [2.8]
#  [2.9]
#  [3. ]
#  [2.8]
#  [3. ]
#  [2.9]
#  [2.6]
#  [2.4]
#  [2.4]
#  [2.7]
#  [2.7]
#  [3. ]
#  [3.4]
#  [3.1]
#  [2.3]
#  [3. ]
#  [2.5]
#  [2.6]
#  [3. ]
#  [2.6]
#  [2.3]
#  [2.7]
#  [3. ]
#  [2.9]
#  [2.9]
#  [2.5]
#  [2.8]
#  [3.3]
#  [2.7]
#  [3. ]
#  [2.9]
#  [3. ]
#  [3. ]
#  [2.5]
#  [2.9]
#  [2.5]
#  [3.6]
#  [3.2]
#  [2.7]
# ...

# %%
data.hist()
plt.show()

# %% [markdown]
# ### Whole Dataset

# %%
sns.pairplot(data, hue='class')

# %% [markdown]
# ### Corelation

# %%
corel = data.corr()
print(corel)
# Out:
#               sepal_length  sepal_width   petal_length  petal_width
# sepal_length      1.000000     -0.103784      0.871283      0.816971
# sepal_width      -0.103784      1.000000     -0.415218     -0.350733
# petal_length      0.871283     -0.415218      1.000000      0.962314
# petal_width       0.816971     -0.350733      0.962314      1.000000

# %% [markdown]
# ### Plot the average

# %%
data = data.values
X = data[:,0:4]
Y = data[:,4]

# %%
Y_Data = np.array([np.average(X[:, i][Y==j].astype('float32')) for i in range (X.shape[1])
 for j in (np.unique(Y))])
Y_Data_reshaped = Y_Data.reshape(4, 3)
Y_Data_reshaped = np.swapaxes(Y_Data_reshaped, 0, 1)
X_axis = np.arange(len(names)-1)
width = 0.25

# %%
plt.bar(X_axis, Y_Data_reshaped[0], width, label = 'Setosa')
plt.bar(X_axis+width, Y_Data_reshaped[1], width, label = 'Versicolour')
plt.bar(X_axis+width*2, Y_Data_reshaped[2], width, label = 'Virginica')
plt.xticks(X_axis, names[:4])
plt.xlabel("Features")
plt.ylabel("Value in cm.")
plt.legend(bbox_to_anchor=(1.3,1))
plt.show()

# %% [markdown]
# ### Testing data

# %%
data = pd.read_csv("Iris.csv")

# %%
x = data.drop(columns="class")
y = data["class"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 119
# 30
# 119
# 30
